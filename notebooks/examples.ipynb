# %% [markdown]
# <a href="https://colab.research.google.com/github/jpdeleon/tql/blob/master/notebooks/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## install tql

# %%
# uncomment to install dependency
# !pip install git+https://github.com/jpdeleon/chronos@master#egg=chronos

# %%
# uncomment to install tql
# !pip install git+https://github.com/jpdeleon/tql@master#egg=tql

# %% [markdown]
# ## short cadence

# %% [markdown]
# ### PDCSAP, SAP

# %%
# %matplotlib inline
import tql

#uses first available sector and PDCSAP lightcurves by default
fig = tql.plot_tql(toiid=125)
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# WARNING: OldEarthOrientationDataWarning: Your version of the IERS Bulletin A is 14.0 days old. For best precision (on the order of arcseconds), you must download an up-to-date IERS Bulletin A table. To do so, run:
#
# >>> from astroplan import download_IERS_A
# >>> download_IERS_A()
#  [astroplan.utils]
# Target: TOI 125
# Available sectors: [1 2]
# Using sector=1.
# Analyzing short cadence data with pipeline mask
# Querying Gaia DR2 catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
# Searching lightcurvefile for TIC 52368076 (sector 1)
# Found 1 lightcurves
# Generalized LS - statistical output
# -----------------------------------
# ...

# %%
#specify sector and lightcurve type
fig = tql.plot_tql(toiid=125, sector=2, lctype='sap')
# Out:
# Target: TOI 125
# Analyzing short cadence data with pipeline mask
# Querying Gaia DR2 catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
# Searching lightcurvefile for TIC 52368076 (sector 2)
# Found 1 lightcurves
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:      16788
# Weighted mean of dataset:   0.999979
# Weighted rms of dataset:    0.001187
# Time base:                  27.403857
# Number of frequency points:   2740
#
# Maximum power p [ZK]: 0.052384
# RMS of residuals:     0.001156
#   Mean weighted internal error:  0.001057
# Best sine frequency:  0.423298 +/- 0.001094
# Best sine period:     2.362401 +/- 0.006106
# Amplitude:            0.000386 +/- 0.000013
# -----------------------------------
#   0%|          | 0/2476 periods | 00:00<?
# Transit Least Squares TLS 1.0.23 (12 March 2019)
# ...

# %% [markdown]
# ### custom aperture shape

# %%
#specify sector and lightcurve type
fig = tql.plot_tql(toiid=125, sector=2, 
                   lctype='custom', sap_mask='square', aper_radius=1)
# Out:
# Target: TOI 125
# Analyzing short cadence data with square mask
# Querying Gaia DR2 catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(23.5934 -66.6763) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
#
# Searching mast for TIC 52368076
#
# 2 tpf(s) found in sector(s) [1, 2]
# Using data from sector 2 only
#
# Loading TIC 52368076 from /home/jp/data/transit/...
#
# Removing scattered light + applying PLD
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:      16788
# Weighted mean of dataset:   0.999992
# Weighted rms of dataset:    0.000627
# Time base:                  27.403857
# Number of frequency points:   2740
#
# Maximum power p [ZK]: 0.045672
# RMS of residuals:     0.000613
#   Mean weighted internal error:  0.000534
# Best sine frequency:  0.423298 +/- 0.001107
# Best sine period:     2.362401 +/- 0.006180
# Amplitude:            0.000191 +/- 0.000007
# ...

# %% [markdown]
# ## long cadence

# %% [markdown]
# ### custom aperture

# %%
#specify long cadence and aperture shape
fig = tql.plot_tql(ticid=291555748, cadence='long', 
                   sap_mask='threshold', threshold_sigma=3,
                   sigma=(10,3)
                  )
# Out:
# TIC 291555748 is TOI 1018!
# Target: TIC 291555748
# Available sectors: [7 8 9]
# Using sector=7.
# Analyzing long cadence data with threshold mask
# Querying Gaia DR2 catalog for ra,dec=(111.716 -50.2666) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(111.716 -50.2666) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
# Searching targetpixelfile for ra,dec=(111.716 -50.2666) using Tesscut
# Removing scattered light + applying PLD
# Querying Gaia DR2 catalog for ra,dec=(111.716 -50.2666) within 120.0 arcsec.
#   0%|          | 0/2156 periods | 00:00<?
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:       1011
# Weighted mean of dataset:   1.000000
# Weighted rms of dataset:    0.000313
# Time base:                  24.416931
# Number of frequency points:   2441
#
# Maximum power p [ZK]: 0.310214
# RMS of residuals:     0.000260
#   Mean weighted internal error:  0.000152
# ...

# %% [markdown]
# ### CDIPS pipeline lightcurve

# %%
#See https://archive.stsci.edu/hlsp/cdips
fig = tql.plot_tql(ticid=88977253, cadence='long', lctype='cdips')
# Out:
# Target: TIC 88977253
# Available sectors: [7]
# Using sector=7.
# Analyzing long cadence data with square mask
# Querying Gaia DR2 catalog for ra,dec=(123.098 -5.76866) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(123.098 -5.76866) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
# Gaia and TIC catalog cross-match succeeded.
# Found 1 CDIPS lightcurves.
# CDIPS has no aperture info in fits. Estimating aperture instead.
# Target: TIC 88977253
# Searching targetpixelfile for ra,dec=(123.098 -5.76866) using Tesscut
# Brightest star is detected far from the center.
# Aperture mask is placed at the center instead.
#   0%|          | 0/2156 periods | 00:00<?
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:       1086
# Weighted mean of dataset:   0.999637
# Weighted rms of dataset:    0.002699
# Time base:                  24.416943
# Number of frequency points:   2441
#
# Maximum power p [ZK]: 0.101709
# ...

# %% [markdown]
# ### PATHOS pipeline lightcurve

# %%
#See https://archive.stsci.edu/hlsp/pathos
fig = tql.plot_tql(ticid=88977253, cadence='long', 
                   lctype='pathos', sigma=(10,3)
                  )
# Out:
# Target: TIC 88977253
# Available sectors: [7]
# Using sector=7.
# Analyzing long cadence data with square mask
# Querying Gaia DR2 catalog for ra,dec=(123.098 -5.76866) within 3.0 arcsec.
# Querying TIC catalog for ra,dec=(123.098 -5.76866) within 3.0 arcsec.
# Gaia and TIC catalog cross-match succeeded.
# PATHOS has no aperture info in fits. Estimating aperture instead.
# Target: TIC 88977253
# Searching targetpixelfile for ra,dec=(123.098 -5.76866) using Tesscut
# Brightest star is detected far from the center.
# Aperture mask is placed at the center instead.
#   0%|          | 0/2158 periods | 00:00<?
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:       1093
# Weighted mean of dataset:   0.999711
# Weighted rms of dataset:    0.003799
# Time base:                  24.437772
# Number of frequency points:   2443
#
# Maximum power p [ZK]: 0.057124
# RMS of residuals:     0.003689
# Best sine frequency:  1.080295 +/- 0.003680
# ...
